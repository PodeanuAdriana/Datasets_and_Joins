# %%
import pandas as pd
import os
import csv

path='./Data/'
filename_read_1=os.path.join(path,"facebook_dataset.csv")
filename_read_2=os.path.join(path,"google_dataset.csv")
filename_read_3=os.path.join(path,"website_dataset.csv")

# am incarcat fisierele csv 
df1=pd.read_csv(filename_read_1,na_values=['NA','?'],on_bad_lines='skip')
df2=pd.read_csv(filename_read_2,na_values=['NA','?'],on_bad_lines='skip')
df3=pd.read_csv(filename_read_3,na_values=['NA','?'],delimiter=';')

# am facut cate un dataframe pentru fiecare fisier si am testat sa vad daca gaseste valori nule pe coloanele de interes

cols1=['categories','name','city','country_name','region_name','phone','domain']
cols2=['category','name','city','country_name','region_name','phone','domain']
cols3=['s_category','legal_name','main_city','main_country','main_region','phone','root_domain']
# df2['phone']=df2.astype('float64')
# voi elimina restul coloanelor din dataframe-uri pentru a lucra mai usor cu restul datelor 
# si a unii coloane care sunt la fel intr-o singura baza de date
# print(df1.head(3))
# print(df2.head(3))
# print(df3.head(3))
coloane_sters1=['country_code','description','email','link','page_type','phone_country_code','region_code','zip_code']
coloane_sters2=['address','country_code','raw_address','raw_phone','region_code','text','zip_code','phone_country_code']
coloane_sters3=['domain_suffix','language','site_name','tld']


df1.drop(columns=coloane_sters1, inplace=True)
df2.drop(columns=coloane_sters2, inplace=True)
df3.drop(columns=coloane_sters3, inplace=True)

# print(df1.head(3))
# print(df2.head(3))
# print(df3.head(3))

# # am eliminat randurile din fiecare dataframe in care am gasit date nule

def randuri_nule_pe_coloane(df,cols):
    df_clean=df.dropna(subset=cols)
    return(df_clean)

df_curat1=randuri_nule_pe_coloane(df1,cols1)
# print(df_curat1)

df_curat2=randuri_nule_pe_coloane(df2,cols2)
# print(df_curat2)

df_curat3=randuri_nule_pe_coloane(df3,cols3)
# print(df_curat3)
# # redenumesc coloanele din dataframe-uri pentru a putea ulterior sa fac join
df1.rename(columns={'categories':'category','country_name':'country','region_name':'region'},inplace=True)
df2.rename(columns={'country_name':'name','region_name':'region'},inplace=True)
df3.rename(columns={'s_category':'category','legal_name':'name','main_city':'city','main_country':'country','main_region':'region',
                   'root_domain':'domain'},inplace=True)
# print(df1.dtypes)
# print(df2.dtypes)

df1['phone']=df1['phone'].astype('object')
# print(df1.dtypes)
# print(df2.dtypes)
# print(df1.head(3))
# print(df2.head(3))
# print(df3.head(3))
# #odata prelucrate seturile de date acum ma ocup de joinuri 

# # o sa creez un join pentru a alatura toate informatiile in functie de coloana categorie
#o sa impart fisierele 
df1.to_csv('output_df1.csv',index=False)
df2.to_csv('output_df2.csv',index=False)

chunk_size=10000
for chunk in pd.read_csv('output_df1.csv',chunksize=chunk_size,dtype='object'):
    for chunk1 in pd.read_csv('output_df2.csv',chunksize=chunk_size,dtype='object'):
        df_joined_12=pd.merge(df1,df2, on='category',how='outer')
        
print(df_joined_12)

df_joined123=pd.merge(df_joines12,df3,on='category',how='outer')
print(df_joined123)
# Out:
# C:\Users\Adriana\AppData\Local\Temp\ipykernel_25392\2864982280.py:12: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv(filename_read_2,na_values=['NA','?'],on_bad_lines='skip')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File D:\Anaconda1\Lib\site-packages\pandas\io\formats\csvs.py:259, in CSVFormatter.save(self)
#     249 self.writer = csvlib.writer(
#     250     handles.handle,
#     251     lineterminator=self.lineterminator,
#    (...)
#     256     quotechar=self.quotechar,
#     257 )
# --> 259 self._save()
#
# File D:\Anaconda1\Lib\site-packages\pandas\io\formats\csvs.py:264, in CSVFormatter._save(self)
#     263     self._save_header()
# --> 264 self._save_body()
#
# File D:\Anaconda1\Lib\site-packages\pandas\io\formats\csvs.py:302, in CSVFormatter._save_body(self)
#     301     break
# ...

# %%
Am ales sa folosesc coloana categorie pentru join deoarece mi se parea relevanta in contextul tuturor celor 3 dataseturi 
de asemenea am preferat prelucrarea fisierelor csv sub forma de dataframe considerand a fi o forma mai usoara nealterand 
fisierele initiale. Informatiile care nu au reprezentat informatii importante precum: zip code,tld,suffix domain etc au fost sterse
    Am consierat de asemenea ca prelucrarea tipului de date ale coloanelor este necesara si redenumirea acestora.
    Am folosit un join outer deoarece am considerat ca toate informatiile prezente in toate cele 3 dataframe-uri sunt importante 
    si ar trebui sa se regaseasca.
